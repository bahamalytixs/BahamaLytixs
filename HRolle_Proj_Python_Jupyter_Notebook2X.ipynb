# %% [markdown]
# <a href="https://colab.research.google.com/github/bahamalytixs/BahamaLytixs/blob/master/HRolle_Proj_Python_Jupyter_Notebook2X.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance==0.1.67
#!pip install pandas==1.3.3
# Out:
# Requirement already satisfied: yfinance==0.1.67 in /usr/local/lib/python3.7/dist-packages (0.1.67)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance==0.1.67) (4.6.4)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.7/dist-packages (from yfinance==0.1.67) (2.23.0)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.7/dist-packages (from yfinance==0.1.67) (1.3.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance==0.1.67) (1.21.5)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance==0.1.67) (0.0.10)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance==0.1.67) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance==0.1.67) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance==0.1.67) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance==0.1.67) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance==0.1.67) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance==0.1.67) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance==0.1.67) (2.10)

# %% [markdown]
# ### Setup for Data Extraction

# %%
import yfinance as yf
import pandas as pd

# %% [markdown]
# ### Tesla Stock Ticker

# %%
tesla = yf.Ticker("TSLA")

# %%
tesla_info = tesla.info
#tesla_info   Commented to save space

# %%
#Extracting ONLY TESLA DATA - for max period
#data = yf.download("TSLA GME", start="2017-01-01", end="2017-04-30", group_by='tickers')
TeslaData = yf.download("TSLA", period="max")   #("TSLA", period="3mo", interval="1wk", group_by='tickers')
tesla_stck = TeslaData.copy()
tesla_stck
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open         High         Low        Close    Adj Close  \
# Date
# 2010-06-29    3.800000     5.000000    3.508000     4.778000     4.778000
# 2010-06-30    5.158000     6.084000    4.660000     4.766000     4.766000
# 2010-07-01    5.000000     5.184000    4.054000     4.392000     4.392000
# 2010-07-02    4.600000     4.620000    3.742000     3.840000     3.840000
# 2010-07-06    4.000000     4.000000    3.166000     3.222000     3.222000
# ...                ...          ...         ...          ...          ...
# 2022-04-11  980.400024  1008.469971  974.640015   975.929993   975.929993
# 2022-04-12  997.640015  1021.190002  976.599976   986.950012   986.950012
# 2022-04-13  981.080017  1026.239990  973.099976  1022.369995  1022.369995
# 2022-04-14  999.289978  1012.710022  982.190002   985.000000   985.000000
# 2022-04-18  989.030029  1014.919983  973.409973  1004.289978  1004.289978
#
#               Volume
# Date
# 2010-06-29  93831500
# 2010-06-30  85935500
# 2010-07-01  41094000
# 2010-07-02  25699000
# 2010-07-06  34334500
# ...              ...
# 2022-04-11  19785700
# 2022-04-12  21992000
# 2022-04-13  18373700
# 2022-04-14  19444000
# 2022-04-18  17182300
#
# [2972 rows x 6 columns]

# %% [markdown]
# ### Qu 1. TESLA Stock Data Head

# %%
tesla_stck.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500
# 2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500
# 2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500

# %%
# data is pd.Dataframe
type(tesla_stck)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### GME Stock Ticker

# %%
gme = yf.Ticker("GME")

# %%
game_info = gme.info
#tesla_info   Commented to save space

# %%
#data = yf.download("TESLA", GME", start="2017-01-01", end="2017-04-30", group_by='tickers')
GameData = yf.download("GME", period="max")   #("GME", period="3mo", interval="1wk", group_by='tickers')
game_stck = GameData.copy()
game_stck
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2002-02-13    9.625000   10.060000    9.525000   10.050000    6.766667
# 2002-02-14   10.175000   10.195000    9.925000   10.000000    6.733000
# 2002-02-15   10.000000   10.025000    9.850000    9.950000    6.699335
# 2002-02-19    9.900000    9.900000    9.375000    9.550000    6.430017
# 2002-02-20    9.600000    9.875000    9.525000    9.875000    6.648839
# ...                ...         ...         ...         ...         ...
# 2022-04-11  143.039993  148.220001  140.610001  146.929993  146.929993
# 2022-04-12  146.500000  152.250000  141.669998  144.869995  144.869995
# 2022-04-13  144.100006  152.130005  142.020004  150.699997  150.699997
# 2022-04-14  149.270004  156.500000  147.220001  150.770004  150.770004
# 2022-04-18  150.000000  151.240005  137.240005  141.460007  141.460007
#
#               Volume
# Date
# 2002-02-13  19054000
# 2002-02-14   2755400
# 2002-02-15   2097400
# 2002-02-19   1852600
# 2002-02-20   1723200
# ...              ...
# 2022-04-11   2453000
# 2022-04-12   1999100
# 2022-04-13   2008200
# 2022-04-14   2498300
# 2022-04-18   2462800
#
# [5080 rows x 6 columns]

# %% [markdown]
# ### QU. 3 -GAMESTOP Stock Head (5 rows) Data

# %%
#GameData.head()
game_stck.head()
# Out:
#               Open    High    Low   Close  Adj Close    Volume
# Date
# 2002-02-13   9.625  10.060  9.525  10.050   6.766667  19054000
# 2002-02-14  10.175  10.195  9.925  10.000   6.733000   2755400
# 2002-02-15  10.000  10.025  9.850   9.950   6.699335   2097400
# 2002-02-19   9.900   9.900  9.375   9.550   6.430017   1852600
# 2002-02-20   9.600   9.875  9.525   9.875   6.648839   1723200

# %% [markdown]
# # * W E B S C R A P I N G *

# %% [markdown]
# ## Tesla Revenue Data - Webscraping

# %%
#!pip install pandas==1.3.3
#!pip install requests==2.26.0
# !mamba install bs4==4.10.0 -y
# !mamba install html5lib==1.1 -y
# !pip install lxml==4.6.4
# !pip install plotly==5.3.1
# !pip install html5lib   #added 15/4/2022
#conda install -c anaconda html5lib   #added 15/4/22
# Out:
# /bin/bash: mamba: command not found
# /bin/bash: mamba: command not found
# Requirement already satisfied: lxml==4.6.4 in /usr/local/lib/python3.7/dist-packages (4.6.4)
# Requirement already satisfied: plotly==5.3.1 in /usr/local/lib/python3.7/dist-packages (5.3.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly==5.3.1) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly==5.3.1) (8.0.1)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.7/dist-packages (1.0.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from html5lib) (1.15.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from html5lib) (0.5.1)

# %%
#!pip install html5lib   #added 15/4/22
#pip install -c anaconda html5lib   #added 15/4/22

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
#url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/amazon_data_webpage.html'
#tesla_url = 'https://finance.yahoo.com/quote/TSLA/financials?p=TSLA'
tesla_url = 'https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue'
htmlTesla_data = requests.get(tesla_url).text

# %%
# Parse Url data to HTML = BeautifulSoup
soupTesla = BeautifulSoup(htmlTesla_data, 'html5lib')

# %%
# Get all TESLA tables - Look for tag 'table'
tesla_tble = soupTesla.find_all('table')
# tesla_tble     # commented to save space

# %%
# Find right table in df of tables
for index,table in enumerate(tesla_tble):
    #if ("Tesla Annual Revenue" in str(table)):
    if ("%"+"Tesla"+"%"+"Revenue"+"%" in str(table)):   #Just in case, have name variation   
        table.index = index       
#print(table.index)  #commented for Spac
print(index)
# Out:
# 5

# %%
# Want the 1st col of table
tesla_Revdata = pd.read_html(str(tesla_tble[1]), flavor='bs4')[0]
tesla_rev = tesla_Revdata.copy()
tesla_rev
# Out:
#    Tesla Quarterly Revenue(Millions of US $)  \
# 0                                 2021-12-31
# 1                                 2021-09-30
# 2                                 2021-06-30
# 3                                 2021-03-31
# 4                                 2020-12-31
# 5                                 2020-09-30
# 6                                 2020-06-30
# 7                                 2020-03-31
# 8                                 2019-12-31
# 9                                 2019-09-30
# 10                                2019-06-30
# 11                                2019-03-31
# 12                                2018-12-31
# 13                                2018-09-30
# 14                                2018-06-30
# 15                                2018-03-31
# 16                                2017-12-31
# 17                                2017-09-30
# 18                                2017-06-30
# 19                                2017-03-31
# 20                                2016-12-31
# 21                                2016-09-30
# 22                                2016-06-30
# 23                                2016-03-31
# 24                                2015-12-31
# 25                                2015-09-30
# 26                                2015-06-30
# 27                                2015-03-31
# 28                                2014-12-31
# 29                                2014-09-30
# 30                                2014-06-30
# 31                                2014-03-31
# 32                                2013-12-31
# 33                                2013-09-30
# 34                                2013-06-30
# 35                                2013-03-31
# 36                                2012-12-31
# 37                                2012-09-30
# 38                                2012-06-30
# 39                                2012-03-31
# 40                                2011-12-31
# 41                                2011-09-30
# 42                                2011-06-30
# 43                                2011-03-31
# 44                                2010-12-31
# 45                                2010-09-30
# 46                                2010-06-30
# 47                                2010-03-31
# 48                                2009-12-31
# 49                                2009-09-30
# 50                                2009-06-30
#
#    Tesla Quarterly Revenue(Millions of US $).1
# 0                                      $17,719
# 1                                      $13,757
# 2                                      $11,958
# 3                                      $10,389
# 4                                      $10,744
# 5                                       $8,771
# 6                                       $6,036
# 7                                       $5,985
# 8                                       $7,384
# 9                                       $6,303
# 10                                      $6,350
# 11                                      $4,541
# 12                                      $7,226
# 13                                      $6,824
# 14                                      $4,002
# 15                                      $3,409
# 16                                      $3,288
# 17                                      $2,985
# 18                                      $2,790
# 19                                      $2,696
# 20                                      $2,285
# 21                                      $2,298
# 22                                      $1,270
# 23                                      $1,147
# 24                                      $1,214
# 25                                        $937
# 26                                        $955
# 27                                        $940
# 28                                        $957
# 29                                        $852
# 30                                        $769
# 31                                        $621
# 32                                        $615
# 33                                        $431
# 34                                        $405
# 35                                        $562
# 36                                        $306
# 37                                         $50
# 38                                         $27
# 39                                         $30
# 40                                         $39
# 41                                         $58
# 42                                         $58
# 43                                         $49
# 44                                         $36
# 45                                         $31
# 46                                         $28
# 47                                         $21
# 48                                         NaN
# 49                                         $46
# 50                                         $27

# %% [markdown]
# ### Qu 2.  Last 5 Rows - TESLA REVENUE DATA

# %%
# Using more readable column names - WITH LAST 5 ROWS
tesla_rev.rename(columns={'Tesla Quarterly Revenue(Millions of US $)': 'Date', 'Tesla Quarterly Revenue(Millions of US $).1': 'Revenue'}, inplace=True)
tesla_rev.tail()
# Out:
#           Date Revenue
# 46  2010-06-30     $28
# 47  2010-03-31     $21
# 48  2009-12-31     NaN
# 49  2009-09-30     $46
# 50  2009-06-30     $27

# %%
list(tesla_stck.columns)  #working code
# Out:
# ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# %%
type(tesla_stck)   #Verify type of data object
# Out:
# pandas.core.frame.DataFrame

# %%
list(tesla_rev.columns)   #Verify type of data object
# Out:
# ['Date', 'Revenue']

# %%
type(tesla_rev)   #Verify type of data object
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Webscraping GME Revenue Data

# %%
#url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/amazon_data_webpage.html'
game_url = 'https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue'
htmlGame_data = requests.get(game_url).text

# %%
# Parse Url data to HTML = BeautifulSoup
soupGame = BeautifulSoup(htmlGame_data, 'html5lib')

# %%
# Get all rows
Game_tble = soupGame.find_all('table')
# game_rows   # commented to save space

# %%
for index,table in enumerate(Game_tble):
    if ("%Game"+"%Revenue%" in str(table)):
        pass      #table_index = index
print(index)
# Out:
# 5

# %%
gme = yf.Ticker("GME")

# %%
#Data extraction from table1
game_RevData = pd.read_html(str(Game_tble[0]), flavor='bs4')[0]
#tesla_data.columns = ["Date", "Rev"]
game_rev = game_RevData.copy()
game_rev
# Out:
#     GameStop Annual Revenue(Millions of US $)  \
# 0                                        2021
# 1                                        2020
# 2                                        2019
# 3                                        2018
# 4                                        2017
# 5                                        2016
# 6                                        2015
# 7                                        2014
# 8                                        2013
# 9                                        2012
# 10                                       2011
# 11                                       2010
# 12                                       2009
#
#    GameStop Annual Revenue(Millions of US $).1
# 0                                       $5,090
# 1                                       $6,466
# 2                                       $8,285
# 3                                       $8,547
# 4                                       $7,965
# 5                                       $9,364
# 6                                       $9,296
# 7                                       $9,040
# 8                                       $8,887
# 9                                       $9,551
# 10                                      $9,474
# 11                                      $9,078
# 12                                      $8,806

# %% [markdown]
# ### Qu 4. GameStop Revenue Tail

# %%
#Renaming GME Columns as Data and Revenue

game_rev.rename(columns={'GameStop Annual Revenue(Millions of US $)': 'Date', 'GameStop Annual Revenue(Millions of US $).1': 'Revenue'}, inplace=True)
game_rev.tail()
# Out:
#     Date Revenue
# 8   2013  $8,887
# 9   2012  $9,551
# 10  2011  $9,474
# 11  2010  $9,078
# 12  2009  $8,806

# %% [markdown]
# ### Tesla Stock & Revenue Dashboard **respectively**

# %%
tesla_stck
# Out:
#                   Open         High         Low        Close    Adj Close  \
# Date
# 2010-06-29    3.800000     5.000000    3.508000     4.778000     4.778000
# 2010-06-30    5.158000     6.084000    4.660000     4.766000     4.766000
# 2010-07-01    5.000000     5.184000    4.054000     4.392000     4.392000
# 2010-07-02    4.600000     4.620000    3.742000     3.840000     3.840000
# 2010-07-06    4.000000     4.000000    3.166000     3.222000     3.222000
# ...                ...          ...         ...          ...          ...
# 2022-04-11  980.400024  1008.469971  974.640015   975.929993   975.929993
# 2022-04-12  997.640015  1021.190002  976.599976   986.950012   986.950012
# 2022-04-13  981.080017  1026.239990  973.099976  1022.369995  1022.369995
# 2022-04-14  999.289978  1012.710022  982.190002   985.000000   985.000000
# 2022-04-18  989.030029  1014.919983  973.409973  1004.289978  1004.289978
#
#               Volume
# Date
# 2010-06-29  93831500
# 2010-06-30  85935500
# 2010-07-01  41094000
# 2010-07-02  25699000
# 2010-07-06  34334500
# ...              ...
# 2022-04-11  19785700
# 2022-04-12  21992000
# 2022-04-13  18373700
# 2022-04-14  19444000
# 2022-04-18  17182300
#
# [2972 rows x 6 columns]

# %%
#  Get TWO Main columns for STOCK DATA (Date, Close)
tesla_stck.reset_index(inplace=True)
#tesla_stck.set_index('Date')
tesla_stck2 = tesla_stck.copy()
tesla_stck2 = tesla_stck[["Date", "Close"]]
tesla_stck2
# Out:
#            Date        Close
# 0    2010-06-29     4.778000
# 1    2010-06-30     4.766000
# 2    2010-07-01     4.392000
# 3    2010-07-02     3.840000
# 4    2010-07-06     3.222000
# ...         ...          ...
# 2967 2022-04-11   975.929993
# 2968 2022-04-12   986.950012
# 2969 2022-04-13  1022.369995
# 2970 2022-04-14   985.000000
# 2971 2022-04-18  1004.289978
#
# [2972 rows x 2 columns]

# %%
tesla_stck2.set_index('Date', inplace=True)     #Reset index to Date field

# %%
#type(tesla_stck2)
tesla_stck2
# Out:
#                   Close
# Date
# 2010-06-29     4.778000
# 2010-06-30     4.766000
# 2010-07-01     4.392000
# 2010-07-02     3.840000
# 2010-07-06     3.222000
# ...                 ...
# 2022-04-11   975.929993
# 2022-04-12   986.950012
# 2022-04-13  1022.369995
# 2022-04-14   985.000000
# 2022-04-18  1004.289978
#
# [2972 rows x 1 columns]

# %% [markdown]
# ### Qu 5. Tesla Stock Plot

# %%
# Displays last 5 rows of TESLA Revenue
#tesla_rev.head()
tesla_rev.set_index('Date', inplace=True)
tesla_rev.head()
# Out:
#             Revenue
# Date
# 2021-12-31  $17,719
# 2021-09-30  $13,757
# 2021-06-30  $11,958
# 2021-03-31  $10,389
# 2020-12-31  $10,744

# %%
#Copy of TELSA_REV in TESLA_REVCPY 
tesla_revCpy = tesla_rev.copy()
tesla_revCpy.tail()
# Out:
#            Revenue
# Date
# 2010-06-30     $28
# 2010-03-31     $21
# 2009-12-31     NaN
# 2009-09-30     $46
# 2009-06-30     $27

# %%
# TESLA Rev data stored in 'tesla_rev'
#Try to remove Reven symbols ($, ,)

import math
tesla_revCpy = tesla_rev.copy()   #Make copy of orig data frame

tesla_revCpy['Revenue'] = tesla_revCpy['Revenue'].apply(lambda x: x.replace('$', '').replace(',', '')
                              if isinstance(x, str) else (0.0 if math.isnan(x)  else x)).astype(float)

tesla_revCpy.head()
#dfCopy
# Out:
#             Revenue
# Date
# 2021-12-31  17719.0
# 2021-09-30  13757.0
# 2021-06-30  11958.0
# 2021-03-31  10389.0
# 2020-12-31  10744.0

# %%
tesla_rev.head()   #Unchanged Data in TESLA_REV - as Expected
# Out:
#             Revenue
# Date
# 2021-12-31  $17,719
# 2021-09-30  $13,757
# 2021-06-30  $11,958
# 2021-03-31  $10,389
# 2020-12-31  $10,744

# %%
# Display dataframe tail vaues - TESLA_REVCPY
tesla_revCpy.tail()
# Out:
#             Revenue
# Date
# 2010-06-30     28.0
# 2010-03-31     21.0
# 2009-12-31      0.0
# 2009-09-30     46.0
# 2009-06-30     27.0

# %% [markdown]
# ### GameStop Stock & Revenue Dashboards respectively

# %%
#  Get TWO Main columns for GME STOCK DATA (Date, Close)
#game_stck = game_data.copy()
#game_stck.reset_index(inplace=True)
#game_stck = game_Stck[["Date", "Close"]]
game_stck
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2002-02-13    9.625000   10.060000    9.525000   10.050000    6.766667
# 2002-02-14   10.175000   10.195000    9.925000   10.000000    6.733000
# 2002-02-15   10.000000   10.025000    9.850000    9.950000    6.699335
# 2002-02-19    9.900000    9.900000    9.375000    9.550000    6.430017
# 2002-02-20    9.600000    9.875000    9.525000    9.875000    6.648839
# ...                ...         ...         ...         ...         ...
# 2022-04-11  143.039993  148.220001  140.610001  146.929993  146.929993
# 2022-04-12  146.500000  152.250000  141.669998  144.869995  144.869995
# 2022-04-13  144.100006  152.130005  142.020004  150.699997  150.699997
# 2022-04-14  149.270004  156.500000  147.220001  150.770004  150.770004
# 2022-04-18  150.000000  151.240005  137.240005  141.460007  141.460007
#
#               Volume
# Date
# 2002-02-13  19054000
# 2002-02-14   2755400
# 2002-02-15   2097400
# 2002-02-19   1852600
# 2002-02-20   1723200
# ...              ...
# 2022-04-11   2453000
# 2022-04-12   1999100
# 2022-04-13   2008200
# 2022-04-14   2498300
# 2022-04-18   2462800
#
# [5080 rows x 6 columns]

# %%
#  Get TWO Main columns for STOCK DATA (Date, Close)
#game_stck.reset_index(inplace=True)
#game_stck.set_index('Date', inplace=True)
game_stck2 = game_stck.copy()

game_stck2.head()
# Out:
#               Open    High    Low   Close  Adj Close    Volume
# Date
# 2002-02-13   9.625  10.060  9.525  10.050   6.766667  19054000
# 2002-02-14  10.175  10.195  9.925  10.000   6.733000   2755400
# 2002-02-15  10.000  10.025  9.850   9.950   6.699335   2097400
# 2002-02-19   9.900   9.900  9.375   9.550   6.430017   1852600
# 2002-02-20   9.600   9.875  9.525   9.875   6.648839   1723200

# %%
game_stck2.reset_index(inplace=True)    #Setup to get Date & close fields

# %%
game_stck2.head()
# Out:
#         Date    Open    High    Low   Close  Adj Close    Volume
# 0 2002-02-13   9.625  10.060  9.525  10.050   6.766667  19054000
# 1 2002-02-14  10.175  10.195  9.925  10.000   6.733000   2755400
# 2 2002-02-15  10.000  10.025  9.850   9.950   6.699335   2097400
# 3 2002-02-19   9.900   9.900  9.375   9.550   6.430017   1852600
# 4 2002-02-20   9.600   9.875  9.525   9.875   6.648839   1723200

# %%
#  Get TWO Main columns for STOCK DATA (Date, Close)
game_stck2.reset_index(inplace=True)   #DO NOT REMOVE
#game_stck2.set_index('Date', inplace=True)

game_stck2 = game_stck2[["Date", "Close"]]
game_stck2.head()
# Out:
#         Date   Close
# 0 2002-02-13  10.050
# 1 2002-02-14  10.000
# 2 2002-02-15   9.950
# 3 2002-02-19   9.550
# 4 2002-02-20   9.875

# %%
game_stck2.set_index('Date', inplace=True)     #Reindex for 'Date' field

# %%
game_stck2.head()
# Out:
#              Close
# Date
# 2002-02-13  10.050
# 2002-02-14  10.000
# 2002-02-15   9.950
# 2002-02-19   9.550
# 2002-02-20   9.875

# %%
#game_revCpy.head()
game_rev.tail()
# Out:
#     Date Revenue
# 8   2013  $8,887
# 9   2012  $9,551
# 10  2011  $9,474
# 11  2010  $9,078
# 12  2009  $8,806

# %%
# conversion of GME Rev data field to float from Currency AND date to 2000-01-01

game_revCpy = game_rev.copy()   #get copy of GME Rev data
game_revCpy['Revenue'] = game_revCpy['Revenue'].apply(lambda x: x.replace('$', '').replace(',', '')
                                if isinstance(x, str) else (0.0 if math.isnan(x) else x)).astype(float)


game_revCpy.head()
# Out:
#    Date  Revenue
# 0  2021   5090.0
# 1  2020   6466.0
# 2  2019   8285.0
# 3  2018   8547.0
# 4  2017   7965.0

# %%
# conversion of GME Rev data field to float from Currency 

import datetime

game_revCpy.reset_index(drop=True)   #drop index

game_revCpy['Date'] = game_revCpy['Date'].apply(lambda x: str(x)+'-01-01'
                                if (not(isinstance(x, datetime.date)) or len(x==4)) else x)     #.astype(date)

# %%
game_revCpy.head()
# Out:
#          Date  Revenue
# 0  2021-01-01   5090.0
# 1  2020-01-01   6466.0
# 2  2019-01-01   8285.0
# 3  2018-01-01   8547.0
# 4  2017-01-01   7965.0

# %%
# Reset index for 'Date' field

game_revCpy.set_index('Date', inplace=True)
game_revCpy.head()
# Out:
#             Revenue
# Date
# 2021-01-01   5090.0
# 2020-01-01   6466.0
# 2019-01-01   8285.0
# 2018-01-01   8547.0
# 2017-01-01   7965.0

# %%
from plotly.subplots import make_subplots

# %%
import plotly.graph_objs as go

# %%
def make_graph(stock_data, revenue_data, stock): 
    fig = make_subplots(rows=2, cols=1, shared_xaxes=True, subplot_titles=("Historical Share Price", "Historical Revenue"), vertical_spacing = .3)
    stock_data_specific = stock_data[stock_data.Date <= '2021--06-14']
    revenue_data_specific = revenue_data[revenue_data.Date <= '2021-04-30']
    fig.add_trace(go.Scatter(x=pd.to_datetime(stock_data_specific.Date, infer_datetime_format=True), y=stock_data_specific.Close.astype("float"), name="Share Price"), row=1, col=1)
    fig.add_trace(go.Scatter(x=pd.to_datetime(revenue_data_specific.Date, infer_datetime_format=True), y=revenue_data_specific.Revenue.astype("float"), name="Revenue"), row=2, col=1)
    fig.update_xaxes(title_text="Date", row=1, col=1)
    fig.update_xaxes(title_text="Date", row=2, col=1)
    fig.update_yaxes(title_text="Price ($US)", row=1, col=1)
    fig.update_yaxes(title_text="Revenue ($US Millions)", row=2, col=1)
    fig.update_layout(showlegend=False, height=900, title=stock, xaxis_rangeslider_visible=True)
    fig.show()

# %%
tesla_revCpy.head()
# Out:
#             Revenue
# Date
# 2021-12-31  17719.0
# 2021-09-30  13757.0
# 2021-06-30  11958.0
# 2021-03-31  10389.0
# 2020-12-31  10744.0

# %%
#Reset Indexes

tesla_stck2.reset_index(inpkace=True)
tesla_revCpy.reset_index(inplace=True)

# %%
tesla_stck2.head()
# Out:
#         Date  Close
# 0 2010-06-29  4.778
# 1 2010-06-30  4.766
# 2 2010-07-01  4.392
# 3 2010-07-02  3.840
# 4 2010-07-06  3.222

# %%
make_graph(tesla_stck2, tesla_revCpy, 'Tesla Data')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="248e7ee2-57a1-453c-9bc1-cd3170442c5d" class="plotly-graph-div" style="height:900px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("248e7ee2-57a1-453c-9bc1-cd3170442c5d")) {                    Plotly.newPlot(                        "248e7ee2-57a1-453c-9bc1-cd3170442c5d",                        [{"name":"Share Price","type":"scatter","x":["2010-06-29T00:00:00","2010-06-30T00:00:00","2010-07-01T00:00:00","2010-07-02T00:00:00","2010-07-06T00:00:00","2010-07-07T00:00:00","2010-07-08T00:00:00","2010-07-09T00:00:00","2010-07-12T00:00:00","2010-07-13T00:00:00","2010-07-14T00:00:00","2010-07-15T00:00:00","2010-07-16T00:00:00","2010-07-19T00:00:00","2010-07-20T00:00:00","2010-07-21T00:00:00","2010-07-22T00:00:00","2010-07-23T00:00:00","2010-07-26T00:00:00","2010-07-27T00:00:00","2010-07-28T00:00:00","2010-07-29T00:00:00","2010-07-30T00:00:00","2010-08-02T00:00:00","2010-08-03T00:00:00","2010-08-04T00:00:00","2010-08-05T00:00:00","2010-08-06T00:00:00","2010-08-09T00:00:00","2010-08-10T00:00:00","2010-08-11T00:00:00","2010-08-12T00:00:00","2010-08-13T00:00:00","2010-08-16T00:00:00","2010-08-17T00:00:00","2010-08-18T00:00:00","2010-08-19T00:00:00","2010-08-20T00:00:00","2010-08-23T00:00:00","2010-08-24T00:00:00","2010-08-25T00:00:00","2010-08-26T00:00:00","2010-08-27T00:00:00","2010-08-30T00:00:00","2010-08-31T00:00:00","2010-09-01T00:00:00","2010-09-02T00:00:00","2010-09-03T00:00:00","2010-09-07T00:00:00","2010-09-08T00:00:00","2010-09-09T00:00:00","2010-09-10T00:00:00","2010-09-13T00:00:00","2010-09-14T00:00:00","2010-09-15T00:00:00","2010-09-16T00:00:00","2010-09-17T00:00:00","2010-09-20T00:00:00","2010-09-21T00:00:00","2010-09-22T00:00:00","2010-09-23T00:00:00","2010-09-24T00:00:00","2010-09-27T00:00:00","2010-09-28T00:00:00","2010-09-29T00:00:00","2010-09-30T00:00:00","2010-10-01T00:00:00","2010-10-04T00:00:00","2010-10-05T00:00:00","2010-10-06T00:00:00","2010-10-07T00:00:00","2010-10-08T00:00:00","2010-10-11T00:00:00","2010-10-12T00:00:00","2010-10-13T00:00:00","2010-10-14T00:00:00","2010-10-15T00:00:00","2010-10-18T00:00:00","2010-10-19T00:00:00","2010-10-20T00:00:00","2010-10-21T00:00:00","2010-10-22T00:00:00","2010-10-25T00:00:00","2010-10-26T00:00:00","2010-10-27T00:00:00","2010-10-28T00:00:00","2010-10-29T00:00:00","2010-11-01T00:00:00","2010-11-02T00:00:00","2010-11-03T00:00:00","2010-11-04T00:00:00","2010-11-05T00:00:00","2010-11-08T00:00:00","2010-11-09T00:00:00","2010-11-10T00:00:00","2010-11-11T00:00:00","2010-11-12T00:00:00","2010-11-15T00:00:00","2010-11-16T00:00:00","2010-11-17T00:00:00","2010-11-18T00:00:00","2010-11-19T00:00:00","2010-11-22T00:00:00","2010-11-23T00:00:00","2010-11-24T00:00:00","2010-11-26T00:00:00","2010-11-29T00:00:00","2010-11-30T00:00:00","2010-12-01T00:00:00","2010-12-02T00:00:00","2010-12-03T00:00:00","2010-12-06T00:00:00","2010-12-07T00:00:00","2010-12-08T00:00:00","2010-12-09T00:00:00","2010-12-10T00:00:00","2010-12-13T00:00:00","2010-12-14T00:00:00","2010-12-15T00:00:00","2010-12-16T00:00:00","2010-12-17T00:00:00","2010-12-20T00:00:00","2010-12-21T00:00:00","2010-12-22T00:00:00","2010-12-23T00:00:00","2010-12-27T00:00:00","2010-12-28T00:00:00","2010-12-29T00:00:00","2010-12-30T00:00:00","2010-12-31T00:00:00","2011-01-03T00:00:00","2011-01-04T00:00:00","2011-01-05T00:00:00","2011-01-06T00:00:00","2011-01-07T00:00:00","2011-01-10T00:00:00","2011-01-11T00:00:00","2011-01-12T00:00:00","2011-01-13T00:00:00","2011-01-14T00:00:00","2011-01-18T00:00:00","2011-01-19T00:00:00","2011-01-20T00:00:00","2011-01-21T00:00:00","2011-01-24T00:00:00","2011-01-25T00:00:00","2011-01-26T00:00:00","2011-01-27T00:00:00","2011-01-28T00:00:00","2011-01-31T00:00:00","2011-02-01T00:00:00","2011-02-02T00:00:00","2011-02-03T00:00:00","2011-02-04T00:00:00","2011-02-07T00:00:00" ...

# %%
game_stck2.head()
#game_revCpy.reset_index('Date', inplace=True)
# Out:
#              Close
# Date
# 2002-02-13  10.050
# 2002-02-14  10.000
# 2002-02-15   9.950
# 2002-02-19   9.550
# 2002-02-20   9.875

# %%
#game_revCpy.reset_index('level_0', drop=True)     #.reset_index(drop=True, inplace=True)
game_revCpy.head()
# Out:
#             Revenue
# Date
# 2021-01-01   5090.0
# 2020-01-01   6466.0
# 2019-01-01   8285.0
# 2018-01-01   8547.0
# 2017-01-01   7965.0

# %%
game_stck2.reset_index(inplace=True)
game_revCpy.reset_index(inplace=True)

# %%
make_graph(game_stck2, game_revCpy, 'GameStop Data')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="0c9b147d-e0ce-4f24-8d99-c862f4d33011" class="plotly-graph-div" style="height:900px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c9b147d-e0ce-4f24-8d99-c862f4d33011")) {                    Plotly.newPlot(                        "0c9b147d-e0ce-4f24-8d99-c862f4d33011",                        [{"name":"Share Price","type":"scatter","x":["2002-02-13T00:00:00","2002-02-14T00:00:00","2002-02-15T00:00:00","2002-02-19T00:00:00","2002-02-20T00:00:00","2002-02-21T00:00:00","2002-02-22T00:00:00","2002-02-25T00:00:00","2002-02-26T00:00:00","2002-02-27T00:00:00","2002-02-28T00:00:00","2002-03-01T00:00:00","2002-03-04T00:00:00","2002-03-05T00:00:00","2002-03-06T00:00:00","2002-03-07T00:00:00","2002-03-08T00:00:00","2002-03-11T00:00:00","2002-03-12T00:00:00","2002-03-13T00:00:00","2002-03-14T00:00:00","2002-03-15T00:00:00","2002-03-18T00:00:00","2002-03-19T00:00:00","2002-03-20T00:00:00","2002-03-21T00:00:00","2002-03-22T00:00:00","2002-03-25T00:00:00","2002-03-26T00:00:00","2002-03-27T00:00:00","2002-03-28T00:00:00","2002-04-01T00:00:00","2002-04-02T00:00:00","2002-04-03T00:00:00","2002-04-04T00:00:00","2002-04-05T00:00:00","2002-04-08T00:00:00","2002-04-09T00:00:00","2002-04-10T00:00:00","2002-04-11T00:00:00","2002-04-12T00:00:00","2002-04-15T00:00:00","2002-04-16T00:00:00","2002-04-17T00:00:00","2002-04-18T00:00:00","2002-04-19T00:00:00","2002-04-22T00:00:00","2002-04-23T00:00:00","2002-04-24T00:00:00","2002-04-25T00:00:00","2002-04-26T00:00:00","2002-04-29T00:00:00","2002-04-30T00:00:00","2002-05-01T00:00:00","2002-05-02T00:00:00","2002-05-03T00:00:00","2002-05-06T00:00:00","2002-05-07T00:00:00","2002-05-08T00:00:00","2002-05-09T00:00:00","2002-05-10T00:00:00","2002-05-13T00:00:00","2002-05-14T00:00:00","2002-05-15T00:00:00","2002-05-16T00:00:00","2002-05-17T00:00:00","2002-05-20T00:00:00","2002-05-21T00:00:00","2002-05-22T00:00:00","2002-05-23T00:00:00","2002-05-24T00:00:00","2002-05-28T00:00:00","2002-05-29T00:00:00","2002-05-30T00:00:00","2002-05-31T00:00:00","2002-06-03T00:00:00","2002-06-04T00:00:00","2002-06-05T00:00:00","2002-06-06T00:00:00","2002-06-07T00:00:00","2002-06-10T00:00:00","2002-06-11T00:00:00","2002-06-12T00:00:00","2002-06-13T00:00:00","2002-06-14T00:00:00","2002-06-17T00:00:00","2002-06-18T00:00:00","2002-06-19T00:00:00","2002-06-20T00:00:00","2002-06-21T00:00:00","2002-06-24T00:00:00","2002-06-25T00:00:00","2002-06-26T00:00:00","2002-06-27T00:00:00","2002-06-28T00:00:00","2002-07-01T00:00:00","2002-07-02T00:00:00","2002-07-03T00:00:00","2002-07-05T00:00:00","2002-07-08T00:00:00","2002-07-09T00:00:00","2002-07-10T00:00:00","2002-07-11T00:00:00","2002-07-12T00:00:00","2002-07-15T00:00:00","2002-07-16T00:00:00","2002-07-17T00:00:00","2002-07-18T00:00:00","2002-07-19T00:00:00","2002-07-22T00:00:00","2002-07-23T00:00:00","2002-07-24T00:00:00","2002-07-25T00:00:00","2002-07-26T00:00:00","2002-07-29T00:00:00","2002-07-30T00:00:00","2002-07-31T00:00:00","2002-08-01T00:00:00","2002-08-02T00:00:00","2002-08-05T00:00:00","2002-08-06T00:00:00","2002-08-07T00:00:00","2002-08-08T00:00:00","2002-08-09T00:00:00","2002-08-12T00:00:00","2002-08-13T00:00:00","2002-08-14T00:00:00","2002-08-15T00:00:00","2002-08-16T00:00:00","2002-08-19T00:00:00","2002-08-20T00:00:00","2002-08-21T00:00:00","2002-08-22T00:00:00","2002-08-23T00:00:00","2002-08-26T00:00:00","2002-08-27T00:00:00","2002-08-28T00:00:00","2002-08-29T00:00:00","2002-08-30T00:00:00","2002-09-03T00:00:00","2002-09-04T00:00:00","2002-09-05T00:00:00","2002-09-06T00:00:00","2002-09-09T00:00:00","2002-09-10T00:00:00","2002-09-11T00:00:00","2002-09-12T00:00:00","2002-09-13T00:00:00","2002-09-16T00:00:00","2002-09-17T00:00:00","2002-09-18T00:00:00","2002-09-19T00:00:00","2002-09-20T00:00:00","2002-09-23T00:00:00","2002-09-24T00:00:00" ...

# %%
# TO DELETE - NOT Called
def make_graphX(tesla_Stck, tesla_Rev, TESLA):

    #from plotly.plotly import iplot
    fig = make_subplots(rows=2,cols=1, shared_xaxes=True, subplot_titles=('Historical Stock Price', 'Historical Revenue'), vertical_spacing = 0.3)
    StckData = tesla_Stck[tesla_Stck.Date <= '2021-06-14']
    RevData = tesla_Rev[tesla_Rev.Date <= '2021-04-30']

    fig.add_trace(go.Scatter(x=pd.to_datetime(StckData.Date, infer_datetime_format=True), y = StckData.Close.astype("float"), name="Share Price"), row=1, col=1)
    fig.add_trace(go.Scatter(x=pd.to_datetime(RevData.Date, infer_datetime_format=True), y = RevData.Revenue.astype("float"), name="Revenue"), row=2, col=1)

    fig.update_xaxes(title_text="Date", row=1, col=1)
    fig.update_xaxes(title_text="Date", row=2, col=1)
    fig.update_yaxes(title_text="Price ($US)", row=1, col=2)
    fig.update_yaxes(title_text="Revenue ($US Millions)", row=2, col=2)
    fig.update_layout(showlegend=False, heigh=900, title='Stock', xaxis_rangeslider_visible=True)
    fig.show()
